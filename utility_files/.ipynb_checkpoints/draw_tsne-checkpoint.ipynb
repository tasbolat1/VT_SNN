# %%
import numpy as np
import pandas as pd
import seaborn as sn
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
n_sample_per_object = 15

# %%
list_of_objects2 = [
    "107-a_pepsi_bottle",
    "107-b_pepsi_bottle",
    "107-c_pepsi_bottle",
    "107-d_pepsi_bottle",
    "107-e_pepsi_bottle",
    "108-a_tuna_fish_can",
    "108-b_tuna_fish_can",
    "108-c_tuna_fish_can",
    "108-d_tuna_fish_can",
    "108-e_tuna_fish_can",
    "109-a_soymilk",
    "109-b_soymilk",
    "109-c_soymilk",
    "109-d_soymilk",
    "109-e_soymilk",
    "110-a_coffee_can",
    "110-b_coffee_can",
    "110-c_coffee_can",
    "110-d_coffee_can",
    "110-e_coffee_can",
]

labels = []
count = 0
overall_count = 0

labels_count = []
for obj in list_of_objects2:
    for i in range(n_sample_per_object):
        labels.append(obj)
        labels_count.append([overall_count, obj])
        overall_count+=1
    count += 1

# %%
labels
# Out:
# ['107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-a_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-b_pepsi_bottle',
#  '107-c_pepsi_bottle',
#  '107-c_pepsi_bottle',
#  '107-c_pepsi_bottle',
#  '107-c_pepsi_bottle',
#  '107-c_pepsi_bottle',
#  '107-c_pepsi_bottle',
#  '107-c_pepsi_bottle',
#  '107-c_pepsi_bottle',
#  '107-c_pepsi_bottle',
#  '107-c_pepsi_bottle',
# ...

# %%
def get_weight(txt):
    if '-a_' in txt:
        return 0
    elif '-b_' in txt:
        return 1
    elif '-c_' in txt:
        return 2
    elif '-d_' in txt:
        return 3
    elif '-e_' in txt:
        return 4
    
def get_object(txt):
        return 0
    elif '-b_' in txt:
        return 1
    elif '-c_' in txt:
        return 2
    elif '-d_' in txt:
        return 3
    elif '-e_' in txt:
        return 4

# %%
weights = []
objects = []

# %%
VR_distances_norm_l = np.load('/home/tasbolat/some_python_examples/aug6/lift_left_vr_distance.npy')

# %%
t_sne = TSNE(n_components=2, metric='precomputed', perplexity=10, random_state=0).fit_transform(VR_distances_norm_l)

# %%
tsne_df = pd.DataFrame(t_sne, columns=['x', 'y'])
tsne_df = tsne_df.assign(labels = labels)

# %%
fig, ax = plt.subplots(figsize=(5,5))
sn.scatterplot(
    x='x', y='y',
    style="labels",
    data =tsne_df,
    legend="full",
    ax=ax,
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-64c324229e61> in <module>
#       5     data =tsne_df,
#       6     legend="full",
# ----> 7     ax=ax,
#       8 )
#       9 plt.show()
#
# ~/tas_python_env/lib/python3.6/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# ...
